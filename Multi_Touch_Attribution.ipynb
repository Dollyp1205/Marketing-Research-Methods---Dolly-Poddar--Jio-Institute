# %% [markdown]
# <a href="https://colab.research.google.com/github/Dollyp1205/Marketing-Research-Methods---Dolly-Poddar--Jio-Institute/blob/Image-and-Video-Analysis/Multi_Touch_Attribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from collections import defaultdict
from itertools import combinations

def first_click_attribution(df):
    first_click = defaultdict(int)
    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            first_channel = eval(journey)[0]
            first_click[first_channel] += 1
    return first_click

def last_click_attribution(df):
    last_click = defaultdict(int)
    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            last_channel = eval(journey)[-1]
            last_click[last_channel] += 1
    return last_click

def shapley_attribution(df):
    channel_contributions = defaultdict(float)

    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            journey = eval(journey)
            unique_channels = list(set(journey))
            num_channels = len(unique_channels)

            for channel in unique_channels:
                marginal_contributions = []

                for i in range(num_channels):
                    for subset in combinations(unique_channels, i):
                        subset = set(subset)
                        with_channel = subset | {channel}
                        marginal_contributions.append(1 / (len(with_channel)))

                channel_contributions[channel] += sum(marginal_contributions) / num_channels

    return channel_contributions

# Load dataset
df = pd.read_csv("/content/multi_touch_attribution_data.csv")

# Compute attributions
first_click = first_click_attribution(df)
last_click = last_click_attribution(df)
shapley_values = shapley_attribution(df)

# Print results
print("First Click Attribution:", first_click)
print("Last Click Attribution:", last_click)
print("Shapley Attribution:", shapley_values)
# Out:
# First Click Attribution: defaultdict(<class 'int'>, {'Display': 275, 'Referral': 290, 'Social Media': 307, 'Search': 291, 'Email': 316, 'Direct': 308})
# Last Click Attribution: defaultdict(<class 'int'>, {'Search': 285, 'Direct': 318, 'Email': 303, 'Social Media': 305, 'Display': 252, 'Referral': 324})
# Shapley Attribution: defaultdict(<class 'float'>, {'Direct': 2226.0830555555544, 'Search': 2164.665833333333, 'Display': 2198.4794444444437, 'Email': 2202.418333333332, 'Social Media': 2281.6513888888876, 'Referral': 2212.5186111111125})

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from itertools import combinations

def first_click_attribution(df):
    first_click = defaultdict(int)
    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            first_channel = eval(journey)[0]
            first_click[first_channel] += 1
    return first_click

def last_click_attribution(df):
    last_click = defaultdict(int)
    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            last_channel = eval(journey)[-1]
            last_click[last_channel] += 1
    return last_click

def shapley_attribution(df):
    channel_contributions = defaultdict(float)

    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            journey = eval(journey)
            unique_channels = list(set(journey))
            num_channels = len(unique_channels)

            for channel in unique_channels:
                marginal_contributions = []

                for i in range(num_channels):
                    for subset in combinations(unique_channels, i):
                        subset = set(subset)
                        with_channel = subset | {channel}
                        marginal_contributions.append(1 / (len(with_channel)))

                channel_contributions[channel] += sum(marginal_contributions) / num_channels

    return channel_contributions

# Load dataset
df = pd.read_csv("/content/multi_touch_attribution_data.csv")

# Compute attributions
first_click = first_click_attribution(df)
last_click = last_click_attribution(df)
shapley_values = shapley_attribution(df)

# Visualization
plt.figure(figsize=(12, 5))

plt.subplot(1, 3, 1)
sns.barplot(x=list(first_click.keys()), y=list(first_click.values()))
plt.title("First Click Attribution")
plt.xticks(rotation=45)

plt.subplot(1, 3, 2)
sns.barplot(x=list(last_click.keys()), y=list(last_click.values()))
plt.title("Last Click Attribution")
plt.xticks(rotation=45)

plt.subplot(1, 3, 3)
sns.barplot(x=list(shapley_values.keys()), y=list(shapley_values.values()))
plt.title("Shapley Attribution")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# Print results
print("First Click Attribution:", first_click)
print("Last Click Attribution:", last_click)
print("Shapley Attribution:", shapley_values)
# Out:
# First Click Attribution: defaultdict(<class 'int'>, {'Display': 275, 'Referral': 290, 'Social Media': 307, 'Search': 291, 'Email': 316, 'Direct': 308})
# Last Click Attribution: defaultdict(<class 'int'>, {'Search': 285, 'Direct': 318, 'Email': 303, 'Social Media': 305, 'Display': 252, 'Referral': 324})
# Shapley Attribution: defaultdict(<class 'float'>, {'Direct': 2226.0830555555544, 'Search': 2164.665833333333, 'Display': 2198.4794444444437, 'Email': 2202.418333333332, 'Social Media': 2281.6513888888876, 'Referral': 2212.5186111111125})

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from itertools import combinations

def first_click_attribution(df):
    first_click = defaultdict(int)
    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            first_channel = eval(journey)[0]
            first_click[first_channel] += 1
    return first_click

def last_click_attribution(df):
    last_click = defaultdict(int)
    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            last_channel = eval(journey)[-1]
            last_click[last_channel] += 1
    return last_click

def shapley_attribution(df):
    channel_contributions = defaultdict(float)

    for journey, conversion in zip(df['journey'], df['converted']):
        if conversion == 1:
            journey = eval(journey)
            unique_channels = list(set(journey))
            num_channels = len(unique_channels)

            for channel in unique_channels:
                marginal_contributions = []

                for i in range(num_channels):
                    for subset in combinations(unique_channels, i):
                        subset = set(subset)
                        with_channel = subset | {channel}
                        marginal_contributions.append(1 / (len(with_channel)))

                channel_contributions[channel] += sum(marginal_contributions) / num_channels

    return channel_contributions

# Load dataset
df = pd.read_csv("/content/multi_touch_attribution_data.csv")

# Compute attributions
first_click = first_click_attribution(df)
last_click = last_click_attribution(df)
shapley_values = shapley_attribution(df)

# Visualization
plt.figure(figsize=(12, 5))

plt.subplot(1, 3, 1)
sns.barplot(x=list(first_click.keys()), y=list(first_click.values()))
plt.title("First Click Attribution")
plt.xticks(rotation=45)

plt.subplot(1, 3, 2)
sns.barplot(x=list(last_click.keys()), y=list(last_click.values()))
plt.title("Last Click Attribution")
plt.xticks(rotation=45)

plt.subplot(1, 3, 3)
sns.barplot(x=list(shapley_values.keys()), y=list(shapley_values.values()))
plt.title("Shapley Attribution")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# Comparison Visualization
comparison_df = pd.DataFrame({
    'First Click': first_click,
    'Last Click': last_click,
    'Shapley': shapley_values
}).fillna(0)

comparison_df.plot(kind='bar', figsize=(12, 6))
plt.title("Comparison of Attribution Models")
plt.xlabel("Marketing Channels")
plt.ylabel("Attributed Conversions")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Print results
print("First Click Attribution:", first_click)
print("Last Click Attribution:", last_click)
print("Shapley Attribution:", shapley_values)
# Out:
# First Click Attribution: defaultdict(<class 'int'>, {'Display': 275, 'Referral': 290, 'Social Media': 307, 'Search': 291, 'Email': 316, 'Direct': 308})
# Last Click Attribution: defaultdict(<class 'int'>, {'Search': 285, 'Direct': 318, 'Email': 303, 'Social Media': 305, 'Display': 252, 'Referral': 324})
# Shapley Attribution: defaultdict(<class 'float'>, {'Direct': 2226.0830555555544, 'Search': 2164.665833333333, 'Display': 2198.4794444444437, 'Email': 2202.418333333332, 'Social Media': 2281.6513888888876, 'Referral': 2212.5186111111125})

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from itertools import combinations
from scipy.sparse import dok_matrix

def first_touch_attribution(df):
    first_touch = defaultdict(float)
    for path, conv_value in zip(df['path'], df['total_conversion_value']):
        first_channel = path.split(' > ')[0]
        first_touch[first_channel] += conv_value
    return first_touch

def last_touch_attribution(df):
    last_touch = defaultdict(float)
    for path, conv_value in zip(df['path'], df['total_conversion_value']):
        last_channel = path.split(' > ')[-1]
        last_touch[last_channel] += conv_value
    return last_touch

def shapley_attribution(df):
    channel_contributions = defaultdict(float)

    for path, conv_value in zip(df['path'], df['total_conversion_value']):
        unique_channels = list(set(path.split(' > ')))
        num_channels = len(unique_channels)

        for channel in unique_channels:
            marginal_contributions = []
            for i in range(num_channels):
                for subset in combinations(unique_channels, i):
                    subset = set(subset)
                    with_channel = subset | {channel}
                    marginal_contributions.append(conv_value / len(with_channel))
            channel_contributions[channel] += sum(marginal_contributions) / num_channels

    return channel_contributions

def markov_chain_attribution(df):
    transition_matrix = defaultdict(lambda: defaultdict(int))
    channel_conversions = defaultdict(float)

    for path, conv_value in zip(df['path'], df['total_conversion_value']):
        channels = ['Start'] + path.split(' > ') + ['Conversion']
        for i in range(len(channels) - 1):
            transition_matrix[channels[i]][channels[i+1]] += 1
        channel_conversions[channels[-2]] += conv_value

    removal_effects = {}
    total_conversions = sum(channel_conversions.values())
    for channel in channel_conversions:
        removed_conversions = total_conversions - channel_conversions[channel]
        removal_effects[channel] = removed_conversions / total_conversions

    return removal_effects

# Load dataset
df = pd.read_csv("/content/MTA dataset.csv")

# Compute attributions
first_touch = first_touch_attribution(df)
last_touch = last_touch_attribution(df)
shapley_values = shapley_attribution(df)
markov_values = markov_chain_attribution(df)

# Create comparison DataFrame
comparison_df = pd.DataFrame({
    'First Touch': first_touch,
    'Last Touch': last_touch,
    'Shapley': shapley_values,
    'Markov Chain': markov_values
}).fillna(0)

# Visualization
comparison_df.plot(kind='bar', figsize=(15, 7))
plt.title("Comparison of Attribution Models")
plt.xlabel("Marketing Channels")
plt.ylabel("Attributed Conversion Value")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Print results
print("First Touch Attribution:", first_touch)
print("Last Touch Attribution:", last_touch)
print("Shapley Attribution:", shapley_values)
print("Markov Chain Attribution:", markov_values)
# Out:
# First Touch Attribution: defaultdict(<class 'float'>, {'eta': 11909.476212937985, 'iota': 19597.26127720401, 'alpha': 19121.272358112994, 'beta': 12235.591744379028, 'theta': 6652.349347462998, 'lambda': 3735.6021648970004, 'gamma': 718.9779918299998, 'epsilon': 412.3012428529999, 'kappa': 305.74325, 'zeta': 103.004, 'mi': 5.273, 'delta': 6.119})
# Last Touch Attribution: defaultdict(<class 'float'>, {'eta': 16754.20380004403, 'iota': 13487.974271440007, 'alpha': 28414.214276793973, 'lambda': 5249.9499854070045, 'kappa': 1069.38425, 'beta': 3850.020987295001, 'theta': 2799.0919875770014, 'epsilon': 2202.6122892860035, 'gamma': 506.01399183400014, 'zeta': 453.26075000000003, 'delta': 10.972, 'mi': 5.273})
# Shapley Attribution: defaultdict(<class 'float'>, {'iota': 42905.88535207057, 'eta': 36213.0280322797, 'alpha': 51551.38224696008, 'beta': 30030.947509756705, 'theta': 23246.735382518284, 'lambda': 14926.820184531049, 'kappa': 4097.8586784523795, 'zeta': 5168.3391813566295, 'epsilon': 8887.647169087319, 'gamma': 2948.6673424536334, 'delta': 53.55205693877549, 'mi': 15.782777777777776})
# Markov Chain Attribution: {'eta': 0.7760222161768217, 'iota': 0.8196866516824128, 'alpha': 0.6201459156909322, 'lambda': 0.9298162910665503, 'kappa': 0.9857039870572791, 'beta': 0.9485311758948047, 'theta': 0.962580470693984, 'epsilon': 0.9705544814266447, 'gamma': 0.9932353758001797, 'zeta': 0.9939406050272133, 'delta': 0.9998533213351446, 'mi': 0.9999295081480328}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from itertools import combinations
from scipy.sparse import dok_matrix

def first_touch_attribution(df):
    first_touch = defaultdict(float)
    for path, conv_value in zip(df['path'], df['total_conversion_value']):
        first_channel = path.split(' > ')[0]
        first_touch[first_channel] += conv_value
    return first_touch

def last_touch_attribution(df):
    last_touch = defaultdict(float)
    for path, conv_value in zip(df['path'], df['total_conversion_value']):
        last_channel = path.split(' > ')[-1]
        last_touch[last_channel] += conv_value
    return last_touch

def shapley_attribution(df):
    channel_contributions = defaultdict(float)

    for path, conv_value in zip(df['path'], df['total_conversion_value']):
        unique_channels = list(set(path.split(' > ')))
        num_channels = len(unique_channels)

        for channel in unique_channels:
            marginal_contributions = []
            for i in range(num_channels):
                for subset in combinations(unique_channels, i):
                    subset = set(subset)
                    with_channel = subset | {channel}
                    marginal_contributions.append(conv_value / len(with_channel))
            channel_contributions[channel] += sum(marginal_contributions) / num_channels

    return channel_contributions

def markov_chain_attribution(df):
    transition_matrix = defaultdict(lambda: defaultdict(int))
    channel_conversions = defaultdict(float)

    for path, conv_value in zip(df['path'], df['total_conversion_value']):
        channels = ['Start'] + path.split(' > ') + ['Conversion']
        for i in range(len(channels) - 1):
            transition_matrix[channels[i]][channels[i+1]] += 1
        channel_conversions[channels[-2]] += conv_value

    removal_effects = {}
    total_conversions = sum(channel_conversions.values())
    for channel in channel_conversions:
        removed_conversions = total_conversions - channel_conversions[channel]
        removal_effects[channel] = removed_conversions / total_conversions

    return removal_effects

# Load dataset
df = pd.read_csv("/content/MTA dataset.csv")

# Compute attributions
first_touch = first_touch_attribution(df)
last_touch = last_touch_attribution(df)
shapley_values = shapley_attribution(df)
markov_values = markov_chain_attribution(df)

# Create comparison DataFrame
comparison_df = pd.DataFrame({
    'First Touch': first_touch,
    'Last Touch': last_touch,
    'Shapley': shapley_values,
    'Markov Chain': markov_values
}).fillna(0)

# Visualization
plt.figure(figsize=(15, 10))

# First Touch Attribution
plt.subplot(2, 2, 1)
sns.barplot(x=list(first_touch.keys()), y=list(first_touch.values()))
plt.title("First Touch Attribution")
plt.xticks(rotation=45)

# Last Touch Attribution
plt.subplot(2, 2, 2)
sns.barplot(x=list(last_touch.keys()), y=list(last_touch.values()))
plt.title("Last Touch Attribution")
plt.xticks(rotation=45)

# Shapley Attribution
plt.subplot(2, 2, 3)
sns.barplot(x=list(shapley_values.keys()), y=list(shapley_values.values()))
plt.title("Shapley Attribution")
plt.xticks(rotation=45)

# Markov Chain Attribution
plt.subplot(2, 2, 4)
sns.barplot(x=list(markov_values.keys()), y=list(markov_values.values()))
plt.title("Markov Chain Attribution")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# Comparison Visualization
comparison_df.plot(kind='bar', figsize=(15, 7))
plt.title("Comparison of Attribution Models")
plt.xlabel("Marketing Channels")
plt.ylabel("Attributed Conversion Value")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Print results
print("First Touch Attribution:", first_touch)
print("Last Touch Attribution:", last_touch)
print("Shapley Attribution:", shapley_values)
print("Markov Chain Attribution:", markov_values)
# Out:
# First Touch Attribution: defaultdict(<class 'float'>, {'eta': 11909.476212937985, 'iota': 19597.26127720401, 'alpha': 19121.272358112994, 'beta': 12235.591744379028, 'theta': 6652.349347462998, 'lambda': 3735.6021648970004, 'gamma': 718.9779918299998, 'epsilon': 412.3012428529999, 'kappa': 305.74325, 'zeta': 103.004, 'mi': 5.273, 'delta': 6.119})
# Last Touch Attribution: defaultdict(<class 'float'>, {'eta': 16754.20380004403, 'iota': 13487.974271440007, 'alpha': 28414.214276793973, 'lambda': 5249.9499854070045, 'kappa': 1069.38425, 'beta': 3850.020987295001, 'theta': 2799.0919875770014, 'epsilon': 2202.6122892860035, 'gamma': 506.01399183400014, 'zeta': 453.26075000000003, 'delta': 10.972, 'mi': 5.273})
# Shapley Attribution: defaultdict(<class 'float'>, {'iota': 42905.88535207057, 'eta': 36213.0280322797, 'alpha': 51551.38224696008, 'beta': 30030.947509756705, 'theta': 23246.735382518284, 'lambda': 14926.820184531049, 'kappa': 4097.8586784523795, 'zeta': 5168.3391813566295, 'epsilon': 8887.647169087319, 'gamma': 2948.6673424536334, 'delta': 53.55205693877549, 'mi': 15.782777777777776})
# Markov Chain Attribution: {'eta': 0.7760222161768217, 'iota': 0.8196866516824128, 'alpha': 0.6201459156909322, 'lambda': 0.9298162910665503, 'kappa': 0.9857039870572791, 'beta': 0.9485311758948047, 'theta': 0.962580470693984, 'epsilon': 0.9705544814266447, 'gamma': 0.9932353758001797, 'zeta': 0.9939406050272133, 'delta': 0.9998533213351446, 'mi': 0.9999295081480328}
